# %%
# ===========================
# Advanced Time Series Forecasting with Attention-based NN
# Single-file Colab-ready script
# Copy entire cell into Google Colab and run
# ===========================

# 0) Install & Imports
# !pip install -q tensorflow numpy pandas matplotlib scikit-learn

import os, random, math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# reproducibility
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)

# 1) Synthetic multivariate dataset (changeable)
T = 1400
t = np.arange(T)

feat1 = 0.02*t + 8*np.sin(0.08*t) + np.random.normal(0, 0.8, T)
feat2 = 4*np.sin(0.03*t + 1.0) + np.random.normal(0, 0.6, T)
feat3 = np.cumsum(np.random.normal(0, 0.05, T)) + 2*np.sin(0.015*t)
target = 0.5*feat1 + 0.35*feat2 + 0.15*feat3 + np.random.normal(0, 0.5, T)

df = pd.DataFrame({
    'feature1': feat1,
    'feature2': feat2,
    'feature3': feat3,
    'target': target
})
print("Dataset created:", df.shape)
display(df.head())

# 2) Scaling & windowing
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(df.values)

SEQ_LEN = 36   # input length
FUTURE = 1     # predict 1 step ahead

def create_dataset(data, seq_len=SEQ_LEN, future=FUTURE):
    X, y = [], []
    for i in range(len(data) - seq_len - future + 1):
        X.append(data[i:i+seq_len, :])          # all features as input
        y.append(data[i+seq_len:i+seq_len+future, 3])  # target column index=3
    return np.array(X), np.array(y)

X, y = create_dataset(data_scaled)
print("X,y shapes:", X.shape, y.shape)

# Train/test split
train_ratio = 0.8
train_size = int(len(X) * train_ratio)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

print("Train/Test:", X_train.shape[0], X_test.shape[0])

# 3) Baseline LSTM
n_features = X.shape[2]

baseline = models.Sequential([
    layers.Input(shape=(SEQ_LEN, n_features)),
    layers.LSTM(64, return_sequences=False),
    layers.Dense(32, activation='relu'),
    layers.Dense(FUTURE, activation='linear')
])
baseline.compile(optimizer='adam', loss='mse', metrics=['mae'])
baseline.summary()

es = EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

print("\nTraining baseline LSTM...")
hist_baseline = baseline.fit(X_train, y_train,
                            validation_split=0.2,
                            epochs=40,
                            batch_size=32,
                            callbacks=[es, rlr],
                            verbose=2)

# 4) Attention layer (Bahdanau) + Encoder -> Context -> Dense decoder
class BahdanauAttention(tf.keras.layers.Layer):
    def __init__(self, units):
        super().__init__()
        self.W1 = layers.Dense(units)
        self.W2 = layers.Dense(units)
        self.V  = layers.Dense(1)
    def call(self, encoder_outputs, hidden_state):
        hidden_with_time_axis = tf.expand_dims(hidden_state, axis=1)  # (batch,1,units)
        score = self.V(tf.nn.tanh(self.W1(encoder_outputs) + self.W2(hidden_with_time_axis)))
        attention_weights = tf.nn.softmax(score, axis=1)  # (batch, seq_len, 1)
        context_vector = attention_weights * encoder_outputs
        context_vector = tf.reduce_sum(context_vector, axis=1)  # (batch, units)
        return context_vector, attention_weights

enc_units = 64
attn_units = 32

encoder_inputs = layers.Input(shape=(SEQ_LEN, n_features))
encoder_outputs, state_h, state_c = layers.LSTM(enc_units, return_sequences=True, return_state=True)(encoder_inputs)

attention = BahdanauAttention(attn_units)
context_vector, attention_weights = attention(encoder_outputs, state_h)

x = layers.Concatenate()([context_vector, state_h])
x = layers.Dense(64, activation='relu')(x)
decoder_output = layers.Dense(FUTURE, activation='linear', name='decoder_output')(x)

# Model that returns prediction + attention weights (for inspection)
attention_model = models.Model(inputs=encoder_inputs, outputs=[decoder_output, attention_weights])
# For training, compile a wrapper that returns only decoder_output
train_model = models.Model(inputs=encoder_inputs, outputs=decoder_output)
train_model.compile(optimizer='adam', loss='mse', metrics=['mae'])
attention_model.summary()
train_model.summary()

print("\nTraining attention-based model...")
hist_attn = train_model.fit(X_train, y_train,
                           validation_split=0.2,
                           epochs=60,
                           batch_size=32,
                           callbacks=[es, rlr],
                           verbose=2)

# 5) Predictions + Metrics
pred_base = baseline.predict(X_test).reshape(-1)
pred_att  = train_model.predict(X_test).reshape(-1)
y_test_flat = y_test.reshape(-1)

def get_metrics(true, pred):
    mae = mean_absolute_error(true, pred)
    rmse = math.sqrt(mean_squared_error(true, pred))
    return mae, rmse

mae_b, rmse_b = get_metrics(y_test_flat, pred_base)
mae_a, rmse_a = get_metrics(y_test_flat, pred_att)

print(f"\nBaseline MAE={mae_b:.6f}, RMSE={rmse_b:.6f}")
print(f"Attention MAE={mae_a:.6f}, RMSE={rmse_a:.6f}")

# 6) Plot sample region (scaled)
plt.figure(figsize=(12,5))
start = 30
end = start + 300
plt.plot(y_test_flat[start:end], label='Actual', linewidth=2)
plt.plot(pred_base[start:end], label='Baseline', linestyle='--')
plt.plot(pred_att[start:end], label='Attention', linestyle=':')
plt.legend(); plt.title('Test slice (scaled)'); plt.show()

# 7) Get attention weights for a sample & heatmap
sample_idx = 15
sample = X_test[sample_idx:sample_idx+1]
pred_val, attn_w = attention_model.predict(sample)
attn_w = attn_w.reshape(-1)  # seq_len

plt.figure(figsize=(10,3))
plt.bar(range(len(attn_w)), attn_w)
plt.title(f'Attention weights (test sample {sample_idx})'); plt.xlabel('timesteps'); plt.show()

# 8) Inverse transform to original scale (target only) - utility
def invert_target(scaled_values):
    arr = np.array(scaled_values).reshape(-1,1)
    filler = np.zeros((arr.shape[0], df.shape[1]-1))
    full = np.concatenate([filler[:, :3], arr], axis=1)
    inv = scaler.inverse_transform(full)[:, 3]
    return inv

inv_true = invert_target(y_test_flat[:200])
inv_base = invert_target(pred_base[:200])
inv_attn = invert_target(pred_att[:200])

plt.figure(figsize=(12,5))
plt.plot(inv_true, label='Actual (orig)')
plt.plot(inv_base, label='Baseline pred')
plt.plot(inv_attn, label='Attention pred')
plt.legend(); plt.title('First 200 test samples (original scale)'); plt.show()

# 9) Save models & figures
os.makedirs('models', exist_ok=True)
baseline.save('models/baseline_lstm.h5')
train_model.save('models/attention_model.h5')
print("Models saved: models/baseline_lstm.h5 , models/attention_model.h5")

# Save a CSV of predictions for report
out_df = pd.DataFrame({
    'actual_scaled': y_test_flat,
    'pred_baseline_scaled': pred_base,
    'pred_attention_scaled': pred_att
})
out_df.to_csv('predictions_scaled.csv', index=False)
print("Predictions saved to predictions_scaled.csv")

# ===========================
# END
# ===========================
# Out:
# Dataset created: (1400, 4)
#    feature1  feature2  feature3    target
# 0  0.397371  2.737737  0.009192  1.280101
# 1  0.548706  3.751188  0.173842  1.068241
# 2  1.832696  4.200844  0.221324  1.927073
# 3  3.180045  3.977880  0.201100  2.527574
# 4  2.409210  4.198030  0.226285  2.763126
# X,y shapes: (1364, 36, 4) (1364, 1)
# Train/Test: 1091 273
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        17,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,777 (77.25 KB)
#  Trainable params: 19,777 (77.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Training baseline LSTM...
# Epoch 1/40
# 28/28 - 3s - 109ms/step - loss: 0.0337 - mae: 0.1372 - val_loss: 0.0079 - val_mae: 0.0734 - learning_rate: 1.0000e-03
# Epoch 2/40
# 28/28 - 1s - 19ms/step - loss: 0.0044 - mae: 0.0538 - val_loss: 0.0035 - val_mae: 0.0491 - learning_rate: 1.0000e-03
# Epoch 3/40
# 28/28 - 1s - 20ms/step - loss: 0.0021 - mae: 0.0380 - val_loss: 0.0030 - val_mae: 0.0467 - learning_rate: 1.0000e-03
# Epoch 4/40
# 28/28 - 1s - 21ms/step - loss: 0.0015 - mae: 0.0314 - val_loss: 0.0033 - val_mae: 0.0491 - learning_rate: 1.0000e-03
# Epoch 5/40
# 28/28 - 1s - 20ms/step - loss: 0.0014 - mae: 0.0305 - val_loss: 0.0033 - val_mae: 0.0496 - learning_rate: 1.0000e-03
# Epoch 6/40
# 28/28 - 1s - 19ms/step - loss: 0.0013 - mae: 0.0286 - val_loss: 0.0024 - val_mae: 0.0412 - learning_rate: 1.0000e-03
# Epoch 7/40
# 28/28 - 1s - 28ms/step - loss: 0.0012 - mae: 0.0278 - val_loss: 0.0022 - val_mae: 0.0385 - learning_rate: 1.0000e-03
# Epoch 8/40
# 28/28 - 1s - 31ms/step - loss: 0.0012 - mae: 0.0271 - val_loss: 0.0017 - val_mae: 0.0333 - learning_rate: 1.0000e-03
# Epoch 9/40
# 28/28 - 1s - 31ms/step - loss: 0.0011 - mae: 0.0266 - val_loss: 0.0014 - val_mae: 0.0295 - learning_rate: 1.0000e-03
# Epoch 10/40
# 28/28 - 1s - 34ms/step - loss: 0.0011 - mae: 0.0262 - val_loss: 0.0013 - val_mae: 0.0278 - learning_rate: 1.0000e-03
# Epoch 11/40
# 28/28 - 1s - 22ms/step - loss: 0.0011 - mae: 0.0260 - val_loss: 0.0012 - val_mae: 0.0271 - learning_rate: 1.0000e-03
# Epoch 12/40
# 28/28 - 1s - 20ms/step - loss: 0.0011 - mae: 0.0258 - val_loss: 0.0012 - val_mae: 0.0267 - learning_rate: 1.0000e-03
# Epoch 13/40
# 28/28 - 1s - 19ms/step - loss: 0.0010 - mae: 0.0258 - val_loss: 0.0011 - val_mae: 0.0266 - learning_rate: 1.0000e-03
# Epoch 14/40
# 28/28 - 1s - 19ms/step - loss: 0.0010 - mae: 0.0257 - val_loss: 0.0011 - val_mae: 0.0265 - learning_rate: 1.0000e-03
# Epoch 15/40
# 28/28 - 1s - 19ms/step - loss: 0.0010 - mae: 0.0257 - val_loss: 0.0011 - val_mae: 0.0264 - learning_rate: 1.0000e-03
# Epoch 16/40
# 28/28 - 1s - 20ms/step - loss: 0.0010 - mae: 0.0256 - val_loss: 0.0011 - val_mae: 0.0263 - learning_rate: 1.0000e-03
# Epoch 17/40
# 28/28 - 1s - 19ms/step - loss: 9.7213e-04 - mae: 0.0248 - val_loss: 0.0012 - val_mae: 0.0271 - learning_rate: 5.0000e-04
# Epoch 18/40
# 28/28 - 1s - 20ms/step - loss: 9.7190e-04 - mae: 0.0248 - val_loss: 0.0012 - val_mae: 0.0271 - learning_rate: 5.0000e-04
# Epoch 19/40
# 28/28 - 1s - 19ms/step - loss: 9.6888e-04 - mae: 0.0247 - val_loss: 0.0012 - val_mae: 0.0271 - learning_rate: 5.0000e-04
# Epoch 20/40
# 28/28 - 1s - 22ms/step - loss: 9.4445e-04 - mae: 0.0244 - val_loss: 9.7073e-04 - val_mae: 0.0250 - learning_rate: 2.5000e-04
# Epoch 21/40
# 28/28 - 1s - 19ms/step - loss: 9.2780e-04 - mae: 0.0242 - val_loss: 9.9558e-04 - val_mae: 0.0252 - learning_rate: 2.5000e-04
# Epoch 22/40
# 28/28 - 1s - 19ms/step - loss: 9.2921e-04 - mae: 0.0242 - val_loss: 9.9149e-04 - val_mae: 0.0252 - learning_rate: 2.5000e-04
# Epoch 23/40
# 28/28 - 1s - 20ms/step - loss: 9.2853e-04 - mae: 0.0242 - val_loss: 9.9022e-04 - val_mae: 0.0252 - learning_rate: 2.5000e-04
# Epoch 24/40
# 28/28 - 1s - 19ms/step - loss: 9.2286e-04 - mae: 0.0242 - val_loss: 9.5997e-04 - val_mae: 0.0249 - learning_rate: 1.2500e-04
# Epoch 25/40
# 28/28 - 1s - 20ms/step - loss: 9.2312e-04 - mae: 0.0242 - val_loss: 9.5690e-04 - val_mae: 0.0249 - learning_rate: 1.2500e-04
# Epoch 26/40
# 28/28 - 1s - 19ms/step - loss: 9.2300e-04 - mae: 0.0242 - val_loss: 9.5721e-04 - val_mae: 0.0249 - learning_rate: 1.2500e-04
# Epoch 27/40
# 28/28 - 1s - 28ms/step - loss: 9.1987e-04 - mae: 0.0241 - val_loss: 9.3094e-04 - val_mae: 0.0246 - learning_rate: 6.2500e-05
# Epoch 28/40
# 28/28 - 1s - 31ms/step - loss: 9.1761e-04 - mae: 0.0241 - val_loss: 9.3330e-04 - val_mae: 0.0246 - learning_rate: 6.2500e-05
# Epoch 29/40
# 28/28 - 1s - 46ms/step - loss: 9.1678e-04 - mae: 0.0240 - val_loss: 9.3411e-04 - val_mae: 0.0246 - learning_rate: 6.2500e-05
# Epoch 30/40
# 28/28 - 1s - 19ms/step - loss: 9.1372e-04 - mae: 0.0240 - val_loss: 9.3677e-04 - val_mae: 0.0247 - learning_rate: 3.1250e-05
# Epoch 31/40
# 28/28 - 1s - 20ms/step - loss: 9.1344e-04 - mae: 0.0240 - val_loss: 9.3621e-04 - val_mae: 0.0247 - learning_rate: 3.1250e-05
# Epoch 32/40
# 28/28 - 1s - 22ms/step - loss: 9.1344e-04 - mae: 0.0240 - val_loss: 9.3627e-04 - val_mae: 0.0247 - learning_rate: 3.1250e-05
# Epoch 33/40
# 28/28 - 1s - 19ms/step - loss: 9.1205e-04 - mae: 0.0240 - val_loss: 9.3807e-04 - val_mae: 0.0247 - learning_rate: 1.5625e-05
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 36, 4)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, 36, 64),  │     17,664 │ input_layer_1[0]… │
# │                     │ (None, 64),       │            │                   │
# │                     │ (None, 64)]       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bahdanau_attention  │ [(None, 64),      │      4,193 │ lstm_1[0][0],     │
# │ (BahdanauAttention) │ (None, 36, 1)]    │            │ lstm_1[0][1]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 128)       │          0 │ bahdanau_attenti… │
# │ (Concatenate)       │                   │            │ lstm_1[0][1]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 64)        │      8,256 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_output      │ (None, 1)         │         65 │ dense_5[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 30,178 (117.88 KB)
#  Trainable params: 30,178 (117.88 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 36, 4)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, 36, 64),  │     17,664 │ input_layer_1[0]… │
# │                     │ (None, 64),       │            │                   │
# │                     │ (None, 64)]       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bahdanau_attention  │ [(None, 64),      │      4,193 │ lstm_1[0][0],     │
# │ (BahdanauAttention) │ (None, 36, 1)]    │            │ lstm_1[0][1]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 128)       │          0 │ bahdanau_attenti… │
# │ (Concatenate)       │                   │            │ lstm_1[0][1]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 64)        │      8,256 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_output      │ (None, 1)         │         65 │ dense_5[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 30,178 (117.88 KB)
#  Trainable params: 30,178 (117.88 KB)
#  Non-trainable params: 0 (0.00 B)
# Training attention-based model...
# Epoch 1/60
# 28/28 - 4s - 150ms/step - loss: 0.0383 - mae: 0.1429 - val_loss: 0.0075 - val_mae: 0.0712 - learning_rate: 1.0000e-03
# Epoch 2/60
# 28/28 - 1s - 23ms/step - loss: 0.0047 - mae: 0.0557 - val_loss: 0.0027 - val_mae: 0.0434 - learning_rate: 1.0000e-03
# Epoch 3/60
# 28/28 - 1s - 22ms/step - loss: 0.0019 - mae: 0.0348 - val_loss: 0.0038 - val_mae: 0.0531 - learning_rate: 1.0000e-03
# Epoch 4/60
# 28/28 - 1s - 22ms/step - loss: 0.0017 - mae: 0.0333 - val_loss: 0.0040 - val_mae: 0.0549 - learning_rate: 1.0000e-03
# Epoch 5/60
# 28/28 - 1s - 23ms/step - loss: 0.0015 - mae: 0.0312 - val_loss: 0.0033 - val_mae: 0.0486 - learning_rate: 1.0000e-03
# Epoch 6/60
# 28/28 - 2s - 58ms/step - loss: 0.0013 - mae: 0.0283 - val_loss: 0.0030 - val_mae: 0.0460 - learning_rate: 5.0000e-04
# Epoch 7/60
# 28/28 - 1s - 35ms/step - loss: 0.0012 - mae: 0.0275 - val_loss: 0.0025 - val_mae: 0.0416 - learning_rate: 5.0000e-04
# Epoch 8/60
# 28/28 - 1s - 38ms/step - loss: 0.0012 - mae: 0.0274 - val_loss: 0.0023 - val_mae: 0.0403 - learning_rate: 5.0000e-04
# Epoch 9/60
# 28/28 - 1s - 22ms/step - loss: 0.0011 - mae: 0.0268 - val_loss: 0.0022 - val_mae: 0.0387 - learning_rate: 5.0000e-04
# Epoch 10/60
# 28/28 - 1s - 22ms/step - loss: 0.0011 - mae: 0.0265 - val_loss: 0.0021 - val_mae: 0.0374 - learning_rate: 5.0000e-04
# Epoch 11/60
# 28/28 - 1s - 23ms/step - loss: 0.0011 - mae: 0.0263 - val_loss: 0.0020 - val_mae: 0.0363 - learning_rate: 5.0000e-04
# Epoch 12/60
# 28/28 - 1s - 23ms/step - loss: 0.0011 - mae: 0.0261 - val_loss: 0.0018 - val_mae: 0.0347 - learning_rate: 5.0000e-04
# Epoch 13/60
# 28/28 - 1s - 24ms/step - loss: 0.0011 - mae: 0.0259 - val_loss: 0.0018 - val_mae: 0.0337 - learning_rate: 5.0000e-04
# Epoch 14/60
# 28/28 - 1s - 24ms/step - loss: 0.0011 - mae: 0.0258 - val_loss: 0.0016 - val_mae: 0.0324 - learning_rate: 5.0000e-04
# Epoch 15/60
# 28/28 - 1s - 22ms/step - loss: 0.0010 - mae: 0.0258 - val_loss: 0.0016 - val_mae: 0.0315 - learning_rate: 5.0000e-04
# Epoch 16/60
# 28/28 - 1s - 22ms/step - loss: 0.0010 - mae: 0.0257 - val_loss: 0.0015 - val_mae: 0.0307 - learning_rate: 5.0000e-04
# Epoch 17/60
# 28/28 - 1s - 23ms/step - loss: 0.0010 - mae: 0.0257 - val_loss: 0.0014 - val_mae: 0.0299 - learning_rate: 5.0000e-04
# Epoch 18/60
# 28/28 - 1s - 22ms/step - loss: 0.0010 - mae: 0.0256 - val_loss: 0.0014 - val_mae: 0.0293 - learning_rate: 5.0000e-04
# Epoch 19/60
# 28/28 - 1s - 23ms/step - loss: 0.0010 - mae: 0.0256 - val_loss: 0.0013 - val_mae: 0.0288 - learning_rate: 5.0000e-04
# Epoch 20/60
# 28/28 - 1s - 22ms/step - loss: 0.0010 - mae: 0.0256 - val_loss: 0.0013 - val_mae: 0.0284 - learning_rate: 5.0000e-04
# Epoch 21/60
# 28/28 - 1s - 21ms/step - loss: 0.0010 - mae: 0.0256 - val_loss: 0.0013 - val_mae: 0.0280 - learning_rate: 5.0000e-04
# Epoch 22/60
# 28/28 - 1s - 22ms/step - loss: 0.0010 - mae: 0.0255 - val_loss: 0.0012 - val_mae: 0.0276 - learning_rate: 5.0000e-04
# Epoch 23/60
# 28/28 - 1s - 22ms/step - loss: 0.0010 - mae: 0.0255 - val_loss: 0.0012 - val_mae: 0.0274 - learning_rate: 5.0000e-04
# Epoch 24/60
# 28/28 - 1s - 35ms/step - loss: 0.0010 - mae: 0.0255 - val_loss: 0.0012 - val_mae: 0.0272 - learning_rate: 5.0000e-04
# Epoch 25/60
# 28/28 - 1s - 35ms/step - loss: 9.5703e-04 - mae: 0.0247 - val_loss: 0.0013 - val_mae: 0.0278 - learning_rate: 2.5000e-04
# Epoch 26/60
# 28/28 - 1s - 35ms/step - loss: 9.5105e-04 - mae: 0.0245 - val_loss: 0.0012 - val_mae: 0.0277 - learning_rate: 2.5000e-04
# Epoch 27/60
# 28/28 - 1s - 23ms/step - loss: 9.5077e-04 - mae: 0.0245 - val_loss: 0.0012 - val_mae: 0.0276 - learning_rate: 2.5000e-04
# Epoch 28/60
# 28/28 - 1s - 22ms/step - loss: 9.2749e-04 - mae: 0.0242 - val_loss: 0.0010 - val_mae: 0.0254 - learning_rate: 1.2500e-04
# Epoch 29/60
# 28/28 - 1s - 25ms/step - loss: 9.1641e-04 - mae: 0.0241 - val_loss: 0.0010 - val_mae: 0.0256 - learning_rate: 1.2500e-04
# Epoch 30/60
# 28/28 - 1s - 21ms/step - loss: 9.1700e-04 - mae: 0.0241 - val_loss: 0.0011 - val_mae: 0.0256 - learning_rate: 1.2500e-04
# Epoch 31/60
# 28/28 - 1s - 22ms/step - loss: 9.1688e-04 - mae: 0.0241 - val_loss: 0.0010 - val_mae: 0.0256 - learning_rate: 1.2500e-04
# Epoch 32/60
# 28/28 - 1s - 22ms/step - loss: 9.1253e-04 - mae: 0.0241 - val_loss: 9.9719e-04 - val_mae: 0.0251 - learning_rate: 6.2500e-05
# Epoch 33/60
# 28/28 - 1s - 22ms/step - loss: 9.1301e-04 - mae: 0.0241 - val_loss: 9.9005e-04 - val_mae: 0.0250 - learning_rate: 6.2500e-05
# Epoch 34/60
# 28/28 - 1s - 23ms/step - loss: 9.1315e-04 - mae: 0.0241 - val_loss: 9.8903e-04 - val_mae: 0.0250 - learning_rate: 6.2500e-05
# Epoch 35/60
# 28/28 - 1s - 22ms/step - loss: 9.0895e-04 - mae: 0.0240 - val_loss: 9.7024e-04 - val_mae: 0.0249 - learning_rate: 3.1250e-05
# Epoch 36/60
# 28/28 - 1s - 23ms/step - loss: 9.0764e-04 - mae: 0.0240 - val_loss: 9.7463e-04 - val_mae: 0.0249 - learning_rate: 3.1250e-05
# Epoch 37/60
# 28/28 - 1s - 23ms/step - loss: 9.0725e-04 - mae: 0.0240 - val_loss: 9.7468e-04 - val_mae: 0.0249 - learning_rate: 3.1250e-05
# Epoch 38/60
# 28/28 - 1s - 22ms/step - loss: 9.0477e-04 - mae: 0.0239 - val_loss: 9.8005e-04 - val_mae: 0.0249 - learning_rate: 1.5625e-05
# Epoch 39/60
# 28/28 - 1s - 23ms/step - loss: 9.0459e-04 - mae: 0.0239 - val_loss: 9.7863e-04 - val_mae: 0.0249 - learning_rate: 1.5625e-05
# Epoch 40/60
# 28/28 - 1s - 23ms/step - loss: 9.0461e-04 - mae: 0.0239 - val_loss: 9.7871e-04 - val_mae: 0.0249 - learning_rate: 1.5625e-05
# Epoch 41/60
# 28/28 - 1s - 22ms/step - loss: 9.0348e-04 - mae: 0.0239 - val_loss: 9.8091e-04 - val_mae: 0.0250 - learning_rate: 7.8125e-06
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step
#
# Baseline MAE=0.025261, RMSE=0.031342
# Attention MAE=0.028568, RMSE=0.035979
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Models saved: models/baseline_lstm.h5 , models/attention_model.h5
# Predictions saved to predictions_scaled.csv
